# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# get the path of the current file
path = os.getcwd()
# get the path of the parent directory
parent_path = os.path.dirname(path)

# %%
# get current directory
dir_path = os.getcwd()
# load "Knowledge-Retrieval-Evaluation-Results.csv"
score_result = pd.read_csv(dir_path + "/Knowledge-Retrieval-Evaluation-Results.csv")

# %%
# show columns of the score_result
print("score_result.columns: ", score_result.columns)
# Out:
# score_result.columns:  Index(['Unnamed: 0.1', 'Unnamed: 0', 'Question', 'Documentation',
#        'ChatGPT3.5-Answer (Without Context)', 'ChatGPT (4) Answer',
#        'GT: Retrieved channel id', 'ChatGPT Direct Answer',
#        'BMZ Chatbot Answer', 'ChatGPT-3.5 Direct Answer Similarity Score',
#        'Chatbot Answer Similarity Score', 'Chatbot Answer Retrieval Precision',
#        'Chatbot Answer Augmentation Accuracy',
#        'Chatbot Answer Augmentation Precision',
#        'Chatbot Answer Augmentation Consistency'],
#       dtype='object')

# %%
# change the column name "ChatGPT (3.5) Answer" to "ChatGPT3.5-Answer (Without Context)"
score_result.rename(columns={"ChatGPT (3.5) Answer": "ChatGPT3.5-Answer (Without Context)"}, inplace=True)
# save the score_result to csv file
score_result.to_csv(dir_path + "/Knowledge-Retrieval-Evaluation-Results.csv", index=False)
# Out:
# /tmp/ipykernel_2683918/310534989.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score_result.rename(columns={"ChatGPT (3.5) Answer": "ChatGPT3.5-Answer (Without Context)"}, inplace=True)

# %%
# plot 'ChatGPT-3.5 Direct Answer Similarity Score',
    #    'Chatbot Answer Similarity Score', 
    #  'Chatbot Answer Retrieval Precision',
    #    'Chatbot Answer Augmentation Accuracy',
    #    'Chatbot Answer Augmentation Precision',
    #    'Chatbot Answer Augmentation Consistency'
plt.figure(figsize=(5,5))
plt.plot(score_result['ChatGPT-3.5 Direct Answer Similarity Score'], label='ChatGPT-3.5 Direct Answer Similarity Score')
plt.plot(score_result['Chatbot Answer Similarity Score'], label='BMZ-Chatbot Answer Similarity Score')
plt.xlabel('Question Index')
plt.ylabel('Similarity Score')
plt.legend()
plt.show()

# %%
# use table to show 'Chatbot Answer Retrieval Precision',
    #    'Chatbot Answer Augmentation Accuracy',
    #    'Chatbot Answer Augmentation Precision',
    #    'Chatbot Answer Augmentation Consistency'
# include the first column 
score_result[['Chatbot Answer Retrieval Precision',
       'Chatbot Answer Augmentation Accuracy',
       'Chatbot Answer Augmentation Precision',
       'Chatbot Answer Augmentation Consistency']]
# Out:
#    Chatbot Answer Retrieval Precision  Chatbot Answer Augmentation Accuracy  \
# 0                                 1.0                                   1.0
# 1                                 1.0                                   1.0
# 2                                 1.0                                   1.0
# 3                                 1.0                                   1.0
# 4                                 1.0                                   1.0
# 5                                 1.0                                   1.0
#
#    Chatbot Answer Augmentation Precision  \
# 0                                    1.0
# 1                                    1.0
# 2                                    1.0
# 3                                    1.0
# 4                                    1.0
# 5                                    1.0
#
#    Chatbot Answer Augmentation Consistency
# 0                                 1.000000
# 1                                 1.000000
# ...
